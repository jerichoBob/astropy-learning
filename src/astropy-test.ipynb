# %%
pip install astropy pytest-astropy --upgrade
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip list
# Out:
# Usage:
#   /opt/homebrew/Cellar/jupyterlab/3.6.1/libexec/bin/python3.11 -m pip install [options] <requirement specifier> [package-index-options] ...
#   /opt/homebrew/Cellar/jupyterlab/3.6.1/libexec/bin/python3.11 -m pip install [options] -r <requirements file> [package-index-options] ...
#   /opt/homebrew/Cellar/jupyterlab/3.6.1/libexec/bin/python3.11 -m pip install [options] [-e] <vcs project url> ...
#   /opt/homebrew/Cellar/jupyterlab/3.6.1/libexec/bin/python3.11 -m pip install [options] [-e] <local project path> ...
#   /opt/homebrew/Cellar/jupyterlab/3.6.1/libexec/bin/python3.11 -m pip install [options] <archive url/path> ...
#
# no such option: --update
# Note: you may need to restart the kernel to use updated packages.

# %%
import astropy

# %%
astropy.test()
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.11.2, pytest-7.2.2, pluggy-1.0.0
#
# Running tests with Astropy version 5.2.1.
# Running tests in /opt/homebrew/Cellar/jupyterlab/3.6.1/libexec/lib/python3.11/site-packages/astropy.
#
# Date: 2023-03-06T10:20:21
#
# Platform: macOS-13.2.1-arm64-arm-64bit
#
# Executable: /opt/homebrew/Cellar/jupyterlab/3.6.1/libexec/bin/python3.11
#
# Full Python Version:
# 3.11.2 (main, Feb 16 2023, 02:55:59) [Clang 14.0.0 (clang-1400.0.29.202)]
#
# encodings: sys: utf-8, locale: UTF-8, filesystem: utf-8
# byteorder: little
# float info: dig: 15, mant_dig: 15
#
# Package versions:
# Numpy: 1.24.2
# Scipy: 1.10.1
# Matplotlib: not available
# h5py: not available
# Pandas: not available
# PyERFA: 2.0.0.1
# Cython: not available
# Scikit-image: not available
# asdf: not available
#
# Using Astropy options: remote_data: none.
#
# ...
